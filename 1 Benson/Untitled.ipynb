# %%
import pandas as pd
import glob
path =r'/Users/Mauro/Desktop/Metis classes/Projects/1 Benson/short_term_data' # use your path
allFiles = glob.glob(path + "/*.txt")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_)
    list_.append(df)
df = pd.concat(list_)
hours=["08:00:00","12:00:00","16:00:00","20:00:00"]

# %%
df.columns=[c.strip() for c in  df.columns]
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
df=df[df["TIME"].isin(hours)]

# %%
df["LINENAME"]=df["LINENAME"].apply(lambda x: ''.join(sorted(x)))

# %%
# Out:
# 1529938

# %%
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/14/2017
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/14/2017
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/14/2017
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/14/2017
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/14/2017
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/14/2017
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/15/2017
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/15/2017
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/15/2017
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/15/2017
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  01/15/2017
# ...

# %%
df=pd.read_csv("short_term_data/turnstile_170121.txt")

# %%
turnstile_170121.txt

# %%
new_df=df.groupby(['C/A', 'UNIT', 'STATION', 'LINENAME'])
gb_aggs=new_df.agg({'SCP':'count','ENTRIES':'sum','EXITS':'sum'})
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py:4036: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# ...

# %%
gb_aggs["TOT"]=gb_aggs.apply( lambda row: row["ENTRIES"]+row["EXITS"],axis=1 )

# %%
# To groupby multiple columns with multiple functions attached
GROUPBY_CA=df.groupby(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME']).count().reset_index()

# %%
GROUPBY_CA=df.groupby(['UNIT', 'STATION', 'LINENAME'])

# %%
GROUPBY_CA.count()
# Out:
#                                     C/A   SCP  DIVISION  DATE  TIME  DESC  \
# UNIT STATION         LINENAME
# R001 SOUTH FERRY     1RW            920   920       920   920   920   920
#      WHITEHALL S-FRY 1RW            638   638       638   638   638   638
# R003 CYPRESS HILLS   J              126   126       126   126   126   126
# R004 75 ST-ELDERTS   JZ             210   210       210   210   210   210
# R005 85 ST-FOREST PK J              168   168       168   168   168   168
# R006 WOODHAVEN BLVD  JZ             356   356       356   356   356   356
# R007 104 ST          JZ             168   168       168   168   168   168
# R008 111 ST          J              168   168       168   168   168   168
# R009 121 ST          JZ             255   255       255   255   255   255
# R010 42 ST-PORT AUTH 1237ACEGNRSW   387   387       387   387   387   387
#                      1237ACENQRSW   420   420       420   420   420   420
# ...

# %%
cumulitave
resets counters
# Out:
#             ENTRIES         EXITS
# count  2.006650e+05  2.006650e+05
# mean   4.033541e+07  3.302435e+07
# std    2.090462e+08  1.925273e+08
# min    0.000000e+00  0.000000e+00
# 25%    4.972240e+05  2.509750e+05
# 50%    2.644156e+06  1.483335e+06
# 75%    6.903097e+06  4.809860e+06
# max    2.130153e+09  2.096934e+09

# %%
df.shape
# Out:
# (200665, 11)

# %%
len(df.STATION.unique())
# Out:
# 373

# %%
len(df.SCP.unique())
# Out:
# 217

# %%
len(df.UNIT.unique())
# Out:
# 464

# %%
len(df["C/A"].unique()) #nearly double
# Out:
# 733

# %%
GROUPBY_CA=df.groupby(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME']).count().reset_index()

# %%
GROUPBY_CA[GROUPBY_CA["STATION"]=="59 ST"]
# Out:
#         C/A  UNIT       SCP STATION LINENAME  DIVISION  DATE  TIME  DESC  \
# 0      A002  R051  02-00-00   59 ST  456NQRW        43    43    43    43
# 1      A002  R051  02-00-01   59 ST  456NQRW        43    43    43    43
# 2      A002  R051  02-03-00   59 ST  456NQRW        43    43    43    43
# 3      A002  R051  02-03-01   59 ST  456NQRW        43    43    43    43
# 4      A002  R051  02-03-02   59 ST  456NQRW        43    43    43    43
# 5      A002  R051  02-03-03   59 ST  456NQRW        43    43    43    43
# 6      A002  R051  02-03-04   59 ST  456NQRW        43    43    43    43
# 7      A002  R051  02-03-05   59 ST  456NQRW        43    43    43    43
# 8      A002  R051  02-03-06   59 ST  456NQRW        43    43    43    43
# 9      A002  R051  02-05-00   59 ST  456NQRW        43    43    43    43
# 10     A002  R051  02-05-01   59 ST  456NQRW        43    43    43    43
# 11     A002  R051  02-06-00   59 ST  456NQRW        43    43    43    43
# ...

# %%
GROUPBY_CA["STATION"].value_counts()
# Out:
# 34 ST-PENN STA     98
# FULTON ST          96
# 23 ST              71
# GRD CNTRL-42 ST    65
# CANAL ST           58
# 34 ST-HERALD SQ    54
# CHAMBERS ST        54
# 59 ST              53
# 86 ST              52
# 42 ST-PORT AUTH    51
# TIMES SQ-42 ST     50
# WALL ST            50
# ATL AV-BARCLAY     48
# PATH NEW WTC       45
# 14 ST              43
# 125 ST             43
# 59 ST COLUMBUS     41
# CORTLANDT ST       39
# 14 ST-UNION SQ     38
# 96 ST              37
# CHURCH AV          37
# 161/YANKEE STAD    37
# 28 ST              37
# 50 ST              36
# METS-WILLETS PT    36
# 47-50 STS ROCK     36
# JAY ST-METROTEC    36
# LEXINGTON AV/53    32
# BOWLING GREEN      29
# FLUSHING-MAIN      27
#                    ..
# 39 AV               3
# KOSCIUSZKO ST       3
# RIT-MANHATTAN       3
# BAY 50 ST           3
# PRESIDENT ST        3
# BOWERY              3
# CYPRESS HILLS       3
# BAYCHESTER AV       3
# NEW LOTS            3
# 238 ST              3
# ...

# %%
new_df=df.groupby(['C/A', 'UNIT', 'STATION', 'LINENAME']).count()
new_df.reset_index().groupby(['C/A', 'UNIT']).count().sort_values("STATION")
# Out:
#             STATION  LINENAME  SCP  DIVISION  DATE  TIME  DESC  ENTRIES  EXITS
# C/A   UNIT
# A002  R051        1         1    1         1     1     1     1        1      1
# R138  R293        1         1    1         1     1     1     1        1      1
# R139  R031        1         1    1         1     1     1     1        1      1
# R141  R031        1         1    1         1     1     1     1        1      1
# R142  R293        1         1    1         1     1     1     1        1      1
# R143  R032        1         1    1         1     1     1     1        1      1
# R145  R032        1         1    1         1     1     1     1        1      1
# R147  R033        1         1    1         1     1     1     1        1      1
# R148  R033        1         1    1         1     1     1     1        1      1
# R137  R031        1         1    1         1     1     1     1        1      1
# R151  R033        1         1    1         1     1     1     1        1      1
# ...

# %%
# Out:
#             STATION  LINENAME  SCP  DIVISION  DATE  TIME  DESC  ENTRIES  \
# C/A   UNIT
# A002  R051        1         1    1         1     1     1     1        1
# R138  R293        1         1    1         1     1     1     1        1
# R139  R031        1         1    1         1     1     1     1        1
# R141  R031        1         1    1         1     1     1     1        1
# R142  R293        1         1    1         1     1     1     1        1
# R143  R032        1         1    1         1     1     1     1        1
# R145  R032        1         1    1         1     1     1     1        1
# R147  R033        1         1    1         1     1     1     1        1
# R148  R033        1         1    1         1     1     1     1        1
# R137  R031        1         1    1         1     1     1     1        1
# R151  R033        1         1    1         1     1     1     1        1
# R155  R116        1         1    1         1     1     1     1        1
# ...

# %%
df.groupby(['C/A', 'UNIT']).count()
# Out:
#             SCP  STATION  LINENAME  DIVISION  DATE  TIME  DESC  ENTRIES  \
# C/A   UNIT
# A002  R051  516      516       516       516   516   516   516      516
# A006  R079  360      360       360       360   360   360   360      360
# A007  R079  252      252       252       252   252   252   252      252
# A010  R080  336      336       336       336   336   336   336      336
# A011  R080  252      252       252       252   252   252   252      252
# A013  R081  252      252       252       252   252   252   252      252
# A014  R081  210      210       210       210   210   210   210      210
# A015  R081  252      252       252       252   252   252   252      252
# A016  R081  210      210       210       210   210   210   210      210
# A021  R032  352      352       352       352   352   352   352      352
# A022  R022  210      210       210       210   210   210   210      210
# A025  R023  420      420       420       420   420   420   420      420
# ...

# %%
GROUPBY_CA=df.groupby(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME']).count().reset_index()

# %%
GROUPBY_CA.groupby(['C/A', 'UNIT']).count()
# Out:
#             SCP  STATION  LINENAME  DIVISION  DATE  TIME  DESC  ENTRIES  \
# C/A   UNIT
# A002  R051   12       12        12        12    12    12    12       12
# A006  R079    8        8         8         8     8     8     8        8
# A007  R079    6        6         6         6     6     6     6        6
# A010  R080    8        8         8         8     8     8     8        8
# A011  R080    6        6         6         6     6     6     6        6
# A013  R081    6        6         6         6     6     6     6        6
# A014  R081    5        5         5         5     5     5     5        5
# A015  R081    6        6         6         6     6     6     6        6
# A016  R081    5        5         5         5     5     5     5        5
# A021  R032    8        8         8         8     8     8     8        8
# A022  R022    5        5         5         5     5     5     5        5
# A025  R023   10       10        10        10    10    10    10       10
# ...

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 100)
pd.set_option('display.precision', 3)

# %%
# read in the file from nyc open data
df = pd.read_csv('NYC_Transit_Subway_Entrance_And_Exit_Data.csv', dtype=str)
df.head()
# Out:
#   Division      Line Station Name Station Latitude Station Longitude Route1  \
# 0      BMT  4 Avenue      25th St        40.660397        -73.998091      R
# 1      BMT  4 Avenue      25th St        40.660397        -73.998091      R
# 2      BMT  4 Avenue      36th St        40.655144        -74.003549      N
# 3      BMT  4 Avenue      36th St        40.655144        -74.003549      N
# 4      BMT  4 Avenue      36th St        40.655144        -74.003549      N
#
#   Route2 Route3 Route4 Route5 Route6 Route7           ...            Staffing  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN           ...                FULL
# 1    NaN    NaN    NaN    NaN    NaN    NaN           ...                NONE
# 2      R    NaN    NaN    NaN    NaN    NaN           ...                FULL
# 3      R    NaN    NaN    NaN    NaN    NaN           ...                FULL
# 4      R    NaN    NaN    NaN    NaN    NaN           ...                FULL
#
# ...

# %%
#remove line names that are empty to prepare for concatenation
df = df.fillna('')
df
# Out:
#      Division               Line                   Station Name  \
# 0         BMT           4 Avenue                        25th St
# 1         BMT           4 Avenue                        25th St
# 2         BMT           4 Avenue                        36th St
# 3         BMT           4 Avenue                        36th St
# 4         BMT           4 Avenue                        36th St
# 5         BMT           4 Avenue                        45th St
# 6         BMT           4 Avenue                        45th St
# 7         BMT           4 Avenue                        45th St
# 8         BMT           4 Avenue                        45th St
# 9         BMT           4 Avenue                        53rd St
# 10        BMT           4 Avenue                        53rd St
# 11        BMT           4 Avenue                        53rd St
# 12        BMT           4 Avenue                        53rd St
# 13        BMT           4 Avenue                        53rd St
# ...

# %%
df.Route11.unique()
# Out:
# array(['', '7'], dtype=object)

# %%
# Concantenate and sort to create new column Line Name
df['Line Name'] = df.Route1 + df.Route2 + df.Route3 + df.Route4 \
                  + df.Route5 + df.Route6 + df.Route7 + df.Route8 \
                  + df.Route9 + df.Route10 + df.Route11
df['Line Name'] = df['Line Name'].apply(lambda x : ''.join(sorted(x)))

# %%
# only keep desired columns
df = df[['Station Name', 'Line Name', 'Station Longitude', 'Station Latitude']]
df
# Out:
#                        Station Name  Line Name Station Longitude  \
# 0                           25th St          R        -73.998091
# 1                           25th St          R        -73.998091
# 2                           36th St         NR        -74.003549
# 3                           36th St         NR        -74.003549
# 4                           36th St         NR        -74.003549
# 5                           45th St          R        -74.010006
# 6                           45th St          R        -74.010006
# 7                           45th St          R        -74.010006
# 8                           45th St          R        -74.010006
# 9                           53rd St          R        -74.014034
# 10                          53rd St          R        -74.014034
# 11                          53rd St          R        -74.014034
# 12                          53rd St          R        -74.014034
# ...

# %%
df['Line Name'].value_counts()
# Out:
# F               125
# 1               120
# 6               113
# 25               92
# A                75
# 7                70
# L                59
# R                48
# D                45
# BD               44
# G                44
# MR               42
# AC               42
# 23               38
# NR               33
# 4                32
# JZ               32
# BQ               31
# BC               29
# 123              26
# 3                25
# CE               24
# C                23
# 1237ACENQRS      22
# NQR              22
# ACE              21
# 2345ACJZ         20
# 123FLM           20
# NQ               20
# ACFR             20
# 1ABCD            17
# 23ACE            17
# BDFM             16
# 4567GS           16
# 6EM              16
# 45               16
# J                15
# 6JNQRZ           15
# BDFMNQR          14
# EJZ              14
# 456              13
# 7BDFM            13
# N                13
# H                12
# 456LNQR          12
# ...

# %%
df['Line Name'] = df['Line Name'].apply(lambda x : x.strip())
# Out:
# /Users/maliksalam/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Line Name'].value_counts()
# Out:
# F               125
# 1               120
# 6               113
# 25               92
# A                75
# 7                70
# L                59
# R                48
# D                45
# BD               44
# G                44
# MR               42
# AC               42
# 23               38
# NR               33
# 4                32
# JZ               32
# BQ               31
# BC               29
# 123              26
# 3                25
# CE               24
# C                23
# 1237ACENQRS      22
# NQR              22
# ACE              21
# 2345ACJZ         20
# 123FLM           20
# NQ               20
# ACFR             20
# 1ABCD            17
# 23ACE            17
# 45               16
# 4567GS           16
# 6EM              16
# BDFM             16
# 4BD              16
# 6JNQRZ           15
# J                15
# EJZ              14
# BDFMNQR          14
# 7BDFM            13
# N                13
# 456              13
# ABCD             12
# ...

# %%
# drop duplicates left over from multiple entrances
df = df.drop_duplicates()
df = df.reset_index()
len(df)
# Out:
# 475

# %%
# drop the newly created index 
df = df.drop('index', axis=1)
df
# Out:
#                        Station Name     Line Name Station Longitude  \
# 0                           25th St             R        -73.998091
# 1                           36th St            NR        -74.003549
# 2                           45th St             R        -74.010006
# 3                           53rd St             R        -74.014034
# 4                           59th St            NR        -74.017881
# 5                           77th St             R         -74.02551
# 6                           86th St             R        -74.028398
# 7                           95th St             R        -74.030876
# 8                            9th St           FGR        -73.988302
# 9          Atlantic Av-Barclays Ctr     2345BDNQR         -73.97881
# 10                     Bay Ridge Av             R        -74.023377
# 11                        DeKalb Av           BQR        -73.981824
# 12                       Pacific St     2345BDNQR         -73.97881
# ...

# %%
# write dataframe to csv
df.to_csv('stations_location', encoding='utf-8', index=False)

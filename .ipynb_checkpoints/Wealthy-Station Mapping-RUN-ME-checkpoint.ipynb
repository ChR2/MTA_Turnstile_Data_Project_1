# %%
# https://data.cityofnewyork.us/api/views/kku6-nxdu/rows.csv?accessType=DOWNLOAD
# https://www.irs.gov/statistics/soi-tax-stats-individual-income-tax-statistics-2015-zip-code-data-soi
import pandas as pd
import numpy as np
import uszipcode
import csv
from collections import defaultdict
import folium
from uszipcode import ZipcodeSearchEngine
import json

# %%
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 250)
pd.set_option('display.precision', 3)

# %%
#input: csv with zip codes with a new york, ny office
# out: list of nyc zip codes in string format
with open('All_NYC_ZipCodes.csv', 'r') as f: #from USPS post office
    reader = csv.reader(f)
    next(reader)
    nyc_zip = list(reader)

nyc_zip = [i[0] for i in nyc_zip]
#print(nyc_zip)

# %%
search = ZipcodeSearchEngine()

# %%
zipcode = search.by_zipcode('11372')
print(zipcode)
# Out:
# {
#     "City": "Jackson Heights",
#     "Density": 90048.64864864865,
#     "HouseOfUnits": 25100,
#     "LandArea": 0.74,
#     "Latitude": 40.7527924,
#     "Longitude": -73.8801301,
#     "NEBoundLatitude": 40.75879200000001,
#     "NEBoundLongitude": -73.86942479999998,
#     "Population": 66636,
#     "SWBoundLatitude": 40.746231,
#     "SWBoungLongitude": -73.897284,
#     "State": "NY",
#     "TotalWages": 1003649658.0,
#     "WaterArea": 0.0,
#     "Wealthy": 15061.673239690257,
#     "Zipcode": "11372",
#     "ZipcodeType": "Standard"
# }

# %%
# input: zipcodes
# output: dictionary with zipcode as key and list of Wealthy, Latitudes as values
search = ZipcodeSearchEngine()

my_dict = defaultdict(int)
for i in nyc_zip:
    zipcode = search.by_zipcode(i)
    
    my_dict[i] = [zipcode.Zipcode,zipcode.Wealthy,zipcode.City,zipcode.Population,zipcode.NEBoundLatitude,zipcode.NEBoundLongitude,zipcode.SWBoundLatitude, zipcode.SWBoungLongitude]

#print(my_dict)

# %%
new_df = pd.DataFrame(my_dict)

# %%
labels = ['Zipcode','Wealthy','City','Population','NEBoundLatitude', 'NEBoundLongitude','SWBoundLatitude', 'SWBoungLongitude']

# %%
new_df.head()
# Out:
#       10001     10002     10003     10004     10005      ...       \
# 0     10001     10002     10003     10004     10005      ...
# 1  4.89e+04  1.71e+04      None  1.08e+05  1.11e+05      ...
# 2  New York  New York  New York  New York  New York      ...
# 3     21102     81410     56024      3089      7135      ...
# 4      40.8      40.7      40.7      40.7      40.7      ...
#
#           11691     11692         11693          11694         11697
# 0         11691     11692         11693          11694         11697
# 1      1.01e+04  1.18e+04      1.75e+04       2.32e+04      3.15e+04
# 2  Far Rockaway   Arverne  Far Rockaway  Rockaway Park  Breezy Point
# 3         60035     18540         11916          20408          4079
# 4          40.6      40.6          40.6           40.6          40.6
#
# [5 rows x 310 columns]

# %%
my_df = new_df.transpose() #flip ittttt

# %%
my_df.head()
# Out:
#            0         1         2      3     4     5     6   7
# 10001  10001  4.89e+04  New York  21102  40.8 -73.9  40.7 -74
# 10002  10002  1.71e+04  New York  81410  40.7   -74  40.7 -74
# 10003  10003      None  New York  56024  40.7   -74  40.7 -74
# 10004  10004  1.08e+05  New York   3089  40.7   -74  40.7 -74
# 10005  10005  1.11e+05  New York   7135  40.7   -74  40.7 -74

# %%
my_df.columns = labels

# %%
my_df.head()
# Out:
#       Zipcode   Wealthy      City Population NEBoundLatitude NEBoundLongitude  \
# 10001   10001  4.89e+04  New York      21102            40.8            -73.9
# 10002   10002  1.71e+04  New York      81410            40.7              -74
# 10003   10003      None  New York      56024            40.7              -74
# 10004   10004  1.08e+05  New York       3089            40.7              -74
# 10005   10005  1.11e+05  New York       7135            40.7              -74
#
#       SWBoundLatitude SWBoungLongitude
# 10001            40.7              -74
# 10002            40.7              -74
# 10003            40.7              -74
# 10004            40.7              -74
# 10005            40.7              -74

# %%
my_df.reset_index(drop = True, inplace = True)

# %%
my_df.head()
# Out:
#   Zipcode   Wealthy      City Population NEBoundLatitude NEBoundLongitude  \
# 0   10001  4.89e+04  New York      21102            40.8            -73.9
# 1   10002  1.71e+04  New York      81410            40.7              -74
# 2   10003      None  New York      56024            40.7              -74
# 3   10004  1.08e+05  New York       3089            40.7              -74
# 4   10005  1.11e+05  New York       7135            40.7              -74
#
#   SWBoundLatitude SWBoungLongitude
# 0            40.7              -74
# 1            40.7              -74
# 2            40.7              -74
# 3            40.7              -74
# 4            40.7              -74

# %%
# #take values list of lists in prep for transformation to dictionary
# new_list = my_dict.values()
# # create labels for columns
# labels = ['Zipcode','Wealthy','City','Population','NEBoundLatitude', 'NEBoundLongitude','SWBoundLatitude', 'SWBoungLongitude']
# #make list of tuples
# list2tuple= [tuple(i) for i in new_list]
# print(list2tuple)

# %%
# #input: list of tuples
# #output: dataframe. finally
# df = pd.DataFrame.from_records(list2tuple, columns=labels)

# %%
# check for number of rows and such

my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 8 columns):
# Zipcode             211 non-null object
# Wealthy             183 non-null object
# City                211 non-null object
# Population          211 non-null object
# NEBoundLatitude     198 non-null object
# NEBoundLongitude    198 non-null object
# SWBoundLatitude     198 non-null object
# SWBoungLongitude    198 non-null object
# dtypes: object(8)
# memory usage: 19.5+ KB

# %%
df_nonull = my_df.dropna()

# %%
#drop all rows with nulls

df_nonull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 0 to 309
# Data columns (total 8 columns):
# Zipcode             181 non-null object
# Wealthy             181 non-null object
# City                181 non-null object
# Population          181 non-null object
# NEBoundLatitude     181 non-null object
# NEBoundLongitude    181 non-null object
# SWBoundLatitude     181 non-null object
# SWBoungLongitude    181 non-null object
# dtypes: object(8)
# memory usage: 12.7+ KB

# %%
df_nonull.loc[df_nonull['Wealthy'] == df_nonull['Wealthy'].max()]
# Out:
#     Zipcode Wealthy      City Population NEBoundLatitude NEBoundLongitude  \
# 19    10020     inf  New York          0            40.8              -74
# 74    10111     inf  New York          0            40.8              -74
# 75    10112     inf  New York          0            40.8              -74
# 116   10168     inf  New York          0            40.8              -74
#
#     SWBoundLatitude SWBoungLongitude
# 19             40.8              -74
# 74             40.8              -74
# 75             40.8              -74
# 116            40.8              -74

# %%
df_nonull = df_nonull[df_nonull.Population != 0]

# %%
df_nonull = df_nonull[df_nonull.Population != 2]

# %%
df_nonull.sort_values('Wealthy', ascending = False)
# Out:
#     Zipcode   Wealthy                 City Population NEBoundLatitude  \
# 6     10007  1.64e+05             New York       6988            40.7
# 17    10018  1.55e+05             New York       5229            40.8
# 161   10282  1.23e+05             New York       4783            40.7
# 4     10005  1.11e+05             New York       7135            40.7
# 50    10069   1.1e+05             New York       5199            40.8
# 3     10004  1.08e+05             New York       3089            40.7
# 16    10017  1.02e+05             New York      16575            40.8
# 5     10006  7.97e+04             New York       3011            40.7
# 52    10075  7.57e+04             New York      26121            40.8
# 159   10280  6.98e+04             New York       7853            40.7
# 35    10036  6.83e+04             New York      24711            40.8
# 9     10010  6.55e+04             New York      31834            40.7
# 11    10012  6.35e+04             New York      24090            40.7
# 214   11109   5.7e+04     Long Island City       3523            40.7
# 0     10001  4.89e+04             New York      21102            40.8
# 37    10038  3.48e+04             New York      20300            40.7
# 262   11363  3.28e+04          Little Neck       6988            40.8
# 230   11217  3.19e+04             Brooklyn      35881            40.7
# 309   11697  3.15e+04         Breezy Point       4079            40.6
# 243   11231  3.11e+04             Brooklyn      33336            40.7
# 207   11040  2.98e+04        New Hyde Park      40782            40.8
# 274   11375  2.89e+04         Forest Hills      68733            40.7
# 203   11001  2.86e+04          Floral Park      26883            40.7
# 198   10471  2.72e+04                Bronx      22922            40.9
# 259   11360  2.63e+04              Bayside      18884            40.8
# 15    10016  2.61e+04             New York      54183            40.8
# 176   10312   2.6e+04        Staten Island      59304            40.6
# 8     10009  2.56e+04             New York      61347            40.7
# 171   10307  2.56e+04        Staten Island      14096            40.5
# 250   11238  2.51e+04             Brooklyn      49262            40.7
# 10    10011  2.48e+04             New York      50984            40.8
# 173   10309  2.48e+04        Staten Island      32519            40.6
# 172   10308  2.47e+04        Staten Island      27357            40.6
# 191   10464  2.39e+04                Bronx       4534            40.9
# 170   10306  2.35e+04        Staten Island      55909            40.6
# 20    10021  2.34e+04             New York      43631            40.8
# 261   11362  2.33e+04          Little Neck      17823            40.8
# 308   11694  2.32e+04        Rockaway Park      20408            40.6
# 21    10022  2.29e+04             New York      31924            40.8
# 256   11357  2.28e+04           Whitestone      39150            40.8
# 222   11209  2.28e+04             Brooklyn      68853            40.6
# 263   11364  2.25e+04      Oakland Gardens      34555            40.8
# 277   11379  2.21e+04       Middle Village      34821            40.7
# 205   11004  2.21e+04            Glen Oaks      14016            40.8
# 177   10314   2.2e+04        Staten Island      85510            40.6
# 294   11426  2.18e+04            Bellerose      17590            40.8
# 282   11414  2.17e+04         Howard Beach      26148            40.7
# 260   11361  2.15e+04              Bayside      28606            40.8
# 34             -73.9            40.8            -73.9
# 245            -73.9            40.7            -73.9
# 254            -73.8            40.7            -73.8
# 226            -73.9            40.7            -73.9
# 268            -73.8            40.8            -73.9
# 244              -74            40.6              -74
# 178            -73.9            40.8            -73.9
# 234            -73.9            40.7            -73.9
# 305            -73.7            40.6            -73.8
# 220            -73.9            40.6            -73.9
# 225            -73.9            40.7            -73.9
# 221            -73.9            40.6            -73.9
# 179            -73.9            40.8            -73.9
# 199            -73.8            40.8            -73.9
# 233              -74            40.6              -74
# 269            -73.9            40.8            -73.9
# 187            -73.9            40.8            -73.9
# 219            -73.9            40.7              -74
# 249            -73.9            40.7            -73.9
# 180            -73.9            40.8            -73.9
# 186            -73.9            40.8            -73.9
# 185            -73.9            40.9            -73.9
# 184            -73.9            40.8            -73.9
# 183            -73.9            40.8            -73.9
# 182            -73.9            40.8            -73.9
# 267            -73.8            40.7            -73.9
# 201            -73.9            40.8            -73.9
# 232              -74            40.6              -74
# 181            -73.9            40.8            -73.9

# %%
df_nonull['Wealthy'].max()
# Out:
# 163592.85289066972

# %%
# (df_nonull['Wealthy'].max() - df_nonull['Wealthy'].min())

# %%
# np.linspace(df_nonull['Wealthy'].min(), df_nonull['Wealthy'].max(), num = 4)

# %%
# make 2 data bases, one with station long/lat, second with top flow station candidates

df_station = pd.read_csv('station_all.csv')
df_top = pd.read_csv('Top_15_Stations_Flow.csv')

# %%
# create Station-Line column in lat/long list
df_station['Station-Line'] = df_station[['Station Name','Line Name']].apply(lambda x: '-'.join(x), axis = 1)

# manual function lol of finding Station-Line name of non-flow targetted stations
df_station[df_station['Station-Line'].str.contains("Columbus")]
# Out:
#      Unnamed: 0             Station Name Line Name  Station Longitude  \
# 156         158  59th St-Columbus Circle     1ABCD            -73.982
#
#      Station Latitude                   Station-Line
# 156            40.768  59th St-Columbus Circle-1ABCD

# %%
#create STATION_LINE column in top flow list
df_top['STATION_LINE'] = df_top[['STATION','LINENAME']].apply(lambda x: '-'.join(x), axis = 1)
df_top.head()
# Out:
#               STATION-LINE-NORM          STATION-NORM          STATION  \
# 0          Grand Central-4567GS         Grand Central  GRD CNTRL-42 ST
# 1               34th St-BDFMNQR               34th St  34 ST-HERALD SQ
# 2            Fulton St-2345ACJZ             Fulton St        FULTON ST
# 3  14th St-Union Square-456LNQR  14th St-Union Square   14 ST-UNION SQ
# 4                   34th St-ACE               34th St   34 ST-PENN STA
#
#    LINENAME    ENTRIES            ...             Delta_time  Delta_people  \
# 0     4567S  3.920e+11            ...              105225881       3753808
# 1  BDFMNQRW  2.440e+11            ...              104138902       3580051
# 2  2345ACJZ  5.550e+11            ...              157759817       3559981
# 3  456LNQRW  1.530e+11            ...               73713600       3438184
# 4       ACE  3.946e+10            ...              119911700       3136693
#
#    Delta_ENTRIES  Delta_EXITS              STATION_LINE
# 0        2107252      1646556     GRD CNTRL-42 ST-4567S
# 1        1942716      1637335  34 ST-HERALD SQ-BDFMNQRW
# 2        2009859      1550122        FULTON ST-2345ACJZ
# 3        1892558      1545626   14 ST-UNION SQ-456LNQRW
# 4        1742297      1394396        34 ST-PENN STA-ACE
#
# [5 rows x 15 columns]

# %%
#create 2 lists of wanted to plot stations

#by flow
flow2plot = df_top['STATION-LINE-NORM']

flow2plot_list = flow2plot.tolist()


#by target audience
audience2plot = []
audience2plot.append("116th St-Columbia University-1") 
# audience2plot.append("8th St-NR")
audience2plot.append("86th St-456")

# %%
#new lat/long dataframe with flow stations to plot
top_flow = df_station[df_station['Station-Line'].isin(flow2plot_list)]

#new lat/long dataframe with audience stations to plot
top_aud = df_station[df_station['Station-Line'].isin(audience2plot)]

# %%
#for flow = create smallter lat/long dataframe and find number of stations to plot
flow_coord = top_flow.loc[:,'Station Longitude':'Station-Line']
#length_flow = len(flow_coord.iloc[:,1])

#for audience= create smallter lat/long dataframe and find number of stations to plot

aud_coord = top_aud.loc[:,'Station Longitude':'Station-Line']
#length_aud = len(aud_coord.iloc[:,1])

# print(coord.iloc[:,1])

#coord

# %% [markdown]
# # MAPPING

# %%
f = r'nyc-zip-code-tabulation-areas-polygons.geojson'
_f = open(f,encoding = "utf-8-sig").read()

folium_map = folium.Map(location=[40.768, -73.982], zoom_start=11.5, tiles="CartoDB dark_matter")

# %%
folium_map.choropleth(geo_data=_f,
                      fill_color='OrRd', fill_opacity=0.7, line_opacity=0.5,
                      threshold_scale = [7000,30000, 60000,90000,110000,165000],legend_name='Average income by zipcode',
                      data = df_nonull,
                      line_color = 'white',
                      key_on='feature.properties.postalCode',
                      columns = ['Zipcode', 'Wealthy'], highlight=True
                     ) 

for j in range(len(flow_coord.iloc[:,1])):
    # print(j)
    #print(coord.iloc[j,1],coord.iloc[j,0])
    folium.RegularPolygonMarker([flow_coord.iloc[j,1], flow_coord.iloc[j,0]],color = 'blue', radius = 5, popup = flow_coord.iloc[j,2]).add_to(folium_map)

for p in range(len(aud_coord.iloc[:,1])):    
    folium.Marker([aud_coord.iloc[p,1], aud_coord.iloc[p,0]],
                  popup=aud_coord.iloc[p,2]).add_to(folium_map)

#color='#DC143C'
folium_map
#folium_map.save('map.html')

# %%
# test = folium.Map(
#     location=[40.749719,-73.987823],
#     zoom_start=12,
#     tiles='Stamen Terrain'
# )


# # folium.Marker([45.3288, -121.6625], popup='<i>Mt. Hood Meadows</i>').add_to(test)


# # test
# for j in range(len(flow_coord.iloc[:,1])):
#     # print(j)
#     #print(coord.iloc[j,1],coord.iloc[j,0])
#     folium.Marker([flow_coord.iloc[j,1], flow_coord.iloc[j,0]], popup = flow_coord.iloc[j,2]).add_to(test)

# for p in range(len(aud_coord.iloc[:,1])):    
#     folium.CircleMarker([aud_coord.iloc[p,1], aud_coord.iloc[p,0]],
#                         radius=10,
#                         popup=aud_coord.iloc[p,2],
#                         color='#DC143C').add_to(test)

    
# test

# # station
